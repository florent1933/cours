# %% [markdown]
# ### Coucou

# %% [markdown]
# Je suis un notebook d'analyse métier, je me concentre sur la compréhension des données et la génération de rapports pour aider à la prise de décision.

# %% [markdown]
# lk

# %%
Hello
