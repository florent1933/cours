# %%
import polars as pl

df = pl.read_csv(
    "../../cours/jeux_de_donnees/ecommerce_pedagogique/input/commandes_brutes.csv"
)


print(df.head(1))

print("---  ---")

print(df.tail(1))


print(df.schema)


print(df.describe())
# Out:
# shape: (1, 13)
# ┌─────────────┬────────────┬────────┬────────────┬───┬──────────┬────────┬────────────┬────────────┐
# │ commande_id ┆ customer_i ┆ client ┆ email      ┆ … ┆ quantite ┆ profit ┆ mode_paiem ┆ region     │
# │ ---         ┆ d          ┆ ---    ┆ ---        ┆   ┆ ---      ┆ ---    ┆ ent        ┆ ---        │
# │ i64         ┆ ---        ┆ str    ┆ str        ┆   ┆ i64      ┆ f64    ┆ ---        ┆ str        │
# │             ┆ str        ┆        ┆            ┆   ┆          ┆        ┆ str        ┆            │
# ╞═════════════╪════════════╪════════╪════════════╪═══╪══════════╪════════╪════════════╪════════════╡
# │ 5001        ┆ C001       ┆ Acme   ┆ orders@acm ┆ … ┆ 12       ┆ 180.5  ┆ Carte      ┆ Ile-de-Fra │
# │             ┆            ┆        ┆ e.com      ┆   ┆          ┆        ┆            ┆ nce        │
# └─────────────┴────────────┴────────┴────────────┴───┴──────────┴────────┴────────────┴────────────┘
# ---  ---
# shape: (1, 13)
# ...

# %%
df.head()
# Out:
# shape: (5, 13)
# ┌────────────┬────────────┬───────────┬────────────┬───┬──────────┬────────┬───────────┬───────────┐
# │ commande_i ┆ customer_i ┆ client    ┆ email      ┆ … ┆ quantite ┆ profit ┆ mode_paie ┆ region    │
# │ d          ┆ d          ┆ ---       ┆ ---        ┆   ┆ ---      ┆ ---    ┆ ment      ┆ ---       │
# │ ---        ┆ ---        ┆ str       ┆ str        ┆   ┆ i64      ┆ f64    ┆ ---       ┆ str       │
# │ i64        ┆ str        ┆           ┆            ┆   ┆          ┆        ┆ str       ┆           │
# ╞════════════╪════════════╪═══════════╪════════════╪═══╪══════════╪════════╪═══════════╪═══════════╡
# │ 5001       ┆ C001       ┆ Acme      ┆ orders@acm ┆ … ┆ 12       ┆ 180.5  ┆ Carte     ┆ Ile-de-Fr │
# │            ┆            ┆           ┆ e.com      ┆   ┆          ┆        ┆           ┆ ance      │
# │ 5002       ┆ C002       ┆ Beta Corp ┆ contact_be ┆ … ┆ 4        ┆ 220.0  ┆ Virement  ┆ Auvergne- │
# ...

# %%
df.schema
# Out:
# Schema([('commande_id', Int64),
#         ('customer_id', String),
#         ('client', String),
#         ('email', String),
#         ('montant', String),
#         ('date_commande', String),
#         ('statut', String),
#         ('categorie', String),
#         ('sous_categorie', String),
#         ('quantite', Int64),
#         ('profit', Float64),
#         ('mode_paiement', String),
#         ('region', String)])
